# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import datasets
X, y = datasets.make_moons(n_samples = 300, noise = 0.3, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])

# %%
# 使用Bagging Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
bagging_clf = BaggingClassifier(DecisionTreeClassifier(), n_estimators=500, max_samples=100, bootstrap=True) # bagging - 放回取样

# %%
bagging_clf.fit(X_train, y_train)
bagging_clf.score(X_test, y_test)
# Out:
# 0.92

# %%
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, y_train)
dt_clf.score(X_test, y_test)
# Out:
# 0.8533333333333334

# %%
bagging_clf2 = BaggingClassifier(DecisionTreeClassifier(), n_estimators=5000, max_samples=100, bootstrap=True) # bagging - 放回取样
bagging_clf2.fit(X_train, y_train)
bagging_clf2.score(X_test, y_test)
# Out:
# 0.92

# %%
bagging_clf.oob_score_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 bagging_clf.oob_score_
#
# AttributeError: 'BaggingClassifier' object has no attribute 'oob_score_'

# %%
# %%time
bagging_clf = BaggingClassifier(DecisionTreeClassifier(), n_estimators=500, max_samples=100, bootstrap=True, oob_score = True) # bagging - 放回取样
bagging_clf.fit(X, y)
#bagging_clf.score(X_test, y_test)
# Out:
# CPU times: total: 781 ms
# Wall time: 1.01 s
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=100,
#                   n_estimators=500, oob_score=True)

# %%
bagging_clf.oob_score_
# Out:
# 0.8733333333333333

# %%
# %%time
bagging_clf = BaggingClassifier(DecisionTreeClassifier(), n_estimators=500, max_samples=100, bootstrap=True, oob_score = True, n_jobs=-1) # bagging - 放回取样
bagging_clf.fit(X, y)
# Out:
# CPU times: total: 297 ms
# Wall time: 1.18 s
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=100,
#                   n_estimators=500, n_jobs=-1, oob_score=True)

# %%
bagging_clf = BaggingClassifier(DecisionTreeClassifier(), n_estimators=500, max_samples=100, bootstrap=True, oob_score = True, n_jobs=-1, max_features=1, bootstrap_features=True) # bagging - 放回取样
bagging_clf.fit(X, y)
# Out:
# BaggingClassifier(bootstrap_features=True, estimator=DecisionTreeClassifier(),
#                   max_features=1, max_samples=100, n_estimators=500, n_jobs=-1,
#                   oob_score=True)

# %%
bagging_clf.oob_score_
# Out:
# 0.8466666666666667
