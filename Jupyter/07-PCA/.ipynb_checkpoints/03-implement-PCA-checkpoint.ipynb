# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.empty((100, 2))

# %%
X.shape
# Out:
# (100, 2)

# %%
X[:, 0] = np.random.uniform(0, 100, size=100)

# %%
X[:, 1] = 0.75*X[:, 0] + 3.0 + np.random.normal(0, 10, size=100)

# %%
plt.scatter(X[:, 0], X[:, 1])

# %%
def demean(X):
    return X - np.mean(X, axis = 0)

# %%
axtest = np.arange(24).reshape(2, 3, 4)

# %% [markdown]
# # demean

# %%
np.mean(X, axis=0)
# Out:
# array([53.10470088, 44.28507108])

# %%
X_demean = demean(X)

# %%
X_demean
# Out:
# array([[  7.49750589,  -7.277353  ],
#        [ 23.18403958,  19.70009195],
#        [ -4.83902858,   6.82853848],
#        [-18.07038223, -21.83728506],
#        [ 14.53136141,   4.30156169],
#        [ 46.76302822,  47.11213457],
#        [ 39.42797212,   9.88526102],
#        [ 25.13894677,   7.83491057],
#        [  7.85501641,   2.73303716],
#        [  2.41928615,   6.7891107 ],
#        [-42.37723573, -16.30537947],
#        [-41.43761792, -42.42243926],
#        [ 44.36335637,  43.34391361],
#        [-23.21556917, -14.8019192 ],
#        [-49.77661322, -25.31124538],
#        [-33.0529927 , -29.89031289],
#        [ -7.37651466, -18.20410274],
#        [ 43.17906291,  30.20788522],
#        [ 23.75590801,  19.33392169],
#        [-11.56156649,  -9.10683234],
#        [ -2.87317232, -22.77183144],
#        [-28.00946997, -32.69279179],
#        [ 23.43350177,   7.52662476],
#        [ 22.48293325,   5.56948686],
#        [-39.10589946, -28.38539329],
#        [-51.88737904, -39.20219864],
#        [ -1.9949067 ,  -9.94284162],
#        [ 37.20396063,  16.58980818],
#        [  9.75103894,   2.46333179],
#        [-49.94950962, -47.4692832 ],
#        [  0.87158539, -11.24933497],
#        [  0.77547881,  -3.18707642],
#        [ 41.04364339,  37.07086231],
#        [ -8.26986834,   0.4650361 ],
#        [  4.15198024,  -4.85719312],
#        [ 17.5948423 ,  19.85072564],
#        [ 30.713431  ,  32.18770265],
#        [ 22.88698692,  27.22164254],
#        [ 37.6514641 ,  21.03888125],
#        [ 23.47520616,  21.03026911],
#        [ 32.2224517 ,  51.6970029 ],
#        [ 43.87933   ,  21.01653099],
#        [-31.54573509, -25.09179764],
#        [ 16.34229873,  13.64807594],
#        [-44.72777422, -18.64815864],
#        [ -0.73066721,  14.72290844],
#        [ -8.1662995 , -16.62396275],
#        [ 17.10653293,   2.26630898],
#        [ 33.11163539,  21.4722103 ],
#        [-19.78267202, -19.35088833],
#        [-50.54131305, -52.86160079],
#        [ 13.13000237,  29.014197  ],
#        [ -8.87456546,   4.4688953 ],
#        [ -3.30348003,   6.10788535],
#        [ 13.91543515,  -3.01672894],
#        [ 27.45866015,  15.49923951],
#        [  7.98348465,  17.23845876],
#        [ 29.4335692 ,  18.94418806],
#        [-51.81790775, -48.83207709],
#        [ 35.11498189,  28.52367432],
#        [-32.44913013,  -7.75031289],
#        [-18.86369423,  -2.71050656],
#        [ 13.59505802,   2.76317906],
#        [ 35.48603394,  16.79645449],
#        [-11.07735448,  -0.53037323],
#        [ -1.09023431,   2.79939768],
#        [-28.11076435, -12.04563088],
#        [  5.70960453,   7.97526339],
#        [-28.54287619,  -7.79920565],
#        [-45.04323694, -36.89867597],
#        [-14.04144588, -27.80509819],
#        [-47.73171347, -27.44981666],
#        [-43.09332822, -39.092076  ],
#        [ 33.95081881,  18.14367828],
#        [  4.70554319,  -3.80363673],
#        [-46.7779819 , -25.95582834],
#        [ -0.28227867,  -0.13032151],
#        [ 10.50530728,   4.70716776],
#        [ 36.0304076 ,  15.42685422],
#        [ 39.51385921,  32.67659868],
#        [ -2.78647616,   9.75505595],
#        [ 30.97290174,  28.11436364],
#        [  5.95721779,   2.05189381],
#        [-38.11867065, -29.55270355],
#        [ 19.10102904,  13.99471514],
#        [ 43.49492401,  46.12941389],
#        [-36.71883771, -34.710925  ],
#        [-46.904945  , -42.20601607],
#        [ 30.77853865,  12.27688303],
#        [-31.74251311, -20.44238346],
#        [ 22.18682206,   6.08803596],
#        [-45.05375744, -21.63986343],
#        [-39.03966196, -23.96717174],
#        [ 26.49785096,  39.87111157],
#        [ 37.75366177,  38.33015845],
#        [  4.40305039,  10.50356847],
#        [-19.42552322,  -4.07919342],
#        [ 22.22103268,  21.68422142],
#        [-23.19482821, -10.94546216],
#        [ -9.33618785, -14.93709916]])

# %%
plt.scatter(X_demean[:, 0], X_demean[:, 1])

# %%
np.mean(X_demean[:, 0])
# Out:
# -3.350208999108872e-14

# %%
np.mean(X_demean[:, 1])
# Out:
# -6.572520305780927e-15

# %% [markdown]
# # 梯度上升发

# %%
def f(X, w):
    return np.sum(X.dot(w)**2)/len(X)

# %%
def df_math(X, w):
    return X.T.dot(X.dot(w))*2/len(X)

# %%
def df_debug(X, w, epsilon=0.0001): # w是一个方向向量，模为1，每个维度的值都很小, 所以epsilon的值也小
    res = np.empty(len(w))
    for i in range(len(w)):
        w_1 = w.copy()
        w_2 = w.copy()
        w_1[i] += epsilon
        w_2[i] -= epsilon
        res[i] = (f(X, w_1) - f(X, w_2)) /(2*epsilon)
    return res

# %%
def direction(w): #求单位向量
    return w / np.linalg.norm(w)

# %%
 def gradient_ascent(df, X, initial_w, eta, n_iters=1e4, epsilon=1e-8):
     w = direction(initial_w)
     i_iter = 0

     while (i_iter < n_iters):
         last_w = w
         gradient = df(X, w)
         w = w + eta*gradient
         w = direction(w)
         if np.abs(f(X, w) - f(X, last_w)) < epsilon:
             break
         i_iter += 1
     return w

# %%
X_b = np.hstack((np.ones((len(X_demean), 1)), X_demean))
initial_w = np.zeros(X_b.shape[1])

# %%
X_b.shape
# Out:
# (100, 3)

# %%
initial_w = np.random.random(X.shape[1])

# %%
initial_w
# Out:
# array([0.0508938 , 0.13110877])

# %%
ww = initial_w /np.linalg.norm(initial_w)

# %%
ww
# Out:
# array([0.36187214, 0.93222774])

# %%
eta = 0.001

# %%
gradient_ascent(df_debug, X_demean, initial_w, eta)
# Out:
# array([0.7845595 , 0.62005354])

# %%
w = gradient_ascent(df_math, X_demean, initial_w, eta)

# %%
plt.scatter(X_demean[:, 0], X_demean[:, 1])
plt.plot((0, w[0] * 50), (0, w[1]*50), color='r')

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.plot([0, w[0] * 50], [0, w[1]*50], color='r')

# %%
w
# Out:
# array([0.7845595 , 0.62005354])

# %%
X2[:, 0] = np.random.uniform(0, 100, size=100)
X2[:, 1] = 0.75*X2[:, 0] + 3.0

# %%
plt.scatter(X2[:, 0], X2[:, 1])
